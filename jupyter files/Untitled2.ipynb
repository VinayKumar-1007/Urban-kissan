# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('mobile.csv')

# %%
data.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
data.n_cores.value_counts(normalize=True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.price_range.value_counts(normalize=True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['battery_power'].hist()
# Out:
# <AxesSubplot:>

# %%
data['battery_power']
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['ocean_proximity']=le.fit_transform(data['ocean_proximity'])

# %%
sns.pairplot(data)

# %%
#There are more number of rooms in new buildings compared to old buildings
#more number of people are residing in low median house values
#There are less population with high income
#as households are increasing total rooms also increasing
#more number of people are willing to stay at 0
#very less population is staying at 2

# %%
plt.scatter(data['population'],data['median_income'])

# %%
#most of the population is middle class
sns.scatterplot(data['population'],data['median_income'])
# Out:
# <AxesSubplot:xlabel='population', ylabel='median_income'>

# %%
sns.scatterplot(data['population'],data['housing_median_age'])
# Out:
# <AxesSubplot:xlabel='population', ylabel='housing_median_age'>

# %%
#most people are willing to buy new buildings
