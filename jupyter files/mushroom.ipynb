# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv("mushrooms.csv")
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
data.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
data.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
np.unique(data.iloc[:,0].values)
# Out:
# array(['e', 'p'], dtype=object)

# %%
m=[]
for i in range(0,23):
   m.append(np.unique(data.iloc[:,i].values))
m
# Out:
# [array(['e', 'p'], dtype=object),
#  array(['b', 'c', 'f', 'k', 's', 'x'], dtype=object),
#  array(['f', 'g', 's', 'y'], dtype=object),
#  array(['b', 'c', 'e', 'g', 'n', 'p', 'r', 'u', 'w', 'y'], dtype=object),
#  array(['f', 't'], dtype=object),
#  array(['a', 'c', 'f', 'l', 'm', 'n', 'p', 's', 'y'], dtype=object),
#  array(['a', 'f'], dtype=object),
#  array(['c', 'w'], dtype=object),
#  array(['b', 'n'], dtype=object),
#  array(['b', 'e', 'g', 'h', 'k', 'n', 'o', 'p', 'r', 'u', 'w', 'y'],
#        dtype=object),
#  array(['e', 't'], dtype=object),
#  array(['?', 'b', 'c', 'e', 'r'], dtype=object),
#  array(['f', 'k', 's', 'y'], dtype=object),
#  array(['f', 'k', 's', 'y'], dtype=object),
#  array(['b', 'c', 'e', 'g', 'n', 'o', 'p', 'w', 'y'], dtype=object),
#  array(['b', 'c', 'e', 'g', 'n', 'o', 'p', 'w', 'y'], dtype=object),
#  array(['p'], dtype=object),
#  array(['n', 'o', 'w', 'y'], dtype=object),
#  array(['n', 'o', 't'], dtype=object),
# ...

# %%
m[1][5]
# Out:
# 'x'

# %%
m[-1]
m[22]
len(m[0])
# Out:
# 2

# %%
c=[]
for column in data.columns:
    c.append(column)
c
# Out:
# ['class',
#  'cap-shape',
#  'cap-surface',
#  'cap-color',
#  'bruises',
#  'odor',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-size',
#  'gill-color',
#  'stalk-shape',
#  'stalk-root',
#  'stalk-surface-above-ring',
#  'stalk-surface-below-ring',
#  'stalk-color-above-ring',
#  'stalk-color-below-ring',
#  'veil-type',
#  'veil-color',
#  'ring-number',
#  'ring-type',
#  'spore-print-color',
#  'population',
#  'habitat']

# %%
for i in range (0,23):
    s=[]
    l=[]
    for j in range(0,len(m[i])):
        s.append(m[i][j])
        l.append(j)
    data[c[i]].replace(s,l,inplace=True)

# %%
data.head()
data["cap-shape"].values
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
data.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
data.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
data.tail()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 8119                         2                       5
# 8120                         2                       5
# ...

# %%
x=data.iloc[:,1:23].values
x
# Out:
# array([[5, 2, 4, ..., 2, 3, 5],
#        [5, 2, 9, ..., 3, 2, 1],
#        [0, 2, 8, ..., 3, 2, 3],
#        ...,
#        [2, 2, 4, ..., 0, 1, 2],
#        [3, 3, 4, ..., 7, 4, 2],
#        [5, 2, 4, ..., 4, 1, 2]], dtype=int64)

# %%
y=data["class"].values
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.svm import SVC
clf=SVC()

# %%
from sklearn.preprocessing import StandardScaler
ssl=StandardScaler()

# %%
x_train=ssl.fit_transform(x_train)
x_test=ssl.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.02476753,  0.1428864 , -0.19443487, ...,  0.17696526,
#          0.28643834,  0.29160496],
#        [ 1.02476753,  0.95577792,  1.373136  , ..., -0.24406142,
#         -0.50831066,  0.8728117 ],
#        [-0.84559949,  0.95577792, -0.19443487, ...,  1.44004531,
#          0.28643834,  0.29160496],
#        ...,
#        [-0.84559949,  0.95577792, -0.19443487, ..., -0.66508811,
#          1.08118734, -0.28960178],
#        [-0.84559949, -1.48289665,  1.76502872, ..., -1.08611479,
#          0.28643834,  1.45401845],
#        [-0.84559949,  0.95577792, -0.19443487, ...,  1.44004531,
#          0.28643834,  0.29160496]])

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
data["cap-shape"]
# Out:
# 0       5
# 1       5
# 2       0
# 3       5
# 4       5
#        ..
# 8119    3
# 8120    5
# 8121    2
# 8122    3
# 8123    5
# Name: cap-shape, Length: 8124, dtype: int64

# %%
p=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(p,y_test)*100
# Out:
# 100.0

# %%
X=data.iloc[:,[21,22]].values
X
# Out:
# array([[3, 5],
#        [2, 1],
#        [2, 3],
#        ...,
#        [1, 2],
#        [4, 2],
#        [1, 2]], dtype=int64)

# %%
Y=data["class"].values
Y
# Out:
# array([1, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
clf.fit(X,Y)
# Out:
# SVC()

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,Y,clf=clf,legend=2)
plt.show()
